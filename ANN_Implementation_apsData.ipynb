# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.12.0

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("/content/aps_failure_training_set1.csv")

# %%
dataset
# Out:
#      class  aa_000 ab_000 ac_000 ad_000 ae_000 af_000 ag_000  ag_001   ag_002  \
# 0      pos  153204      0    182     na      0      0      0       0        0
# 1      pos  453236     na   2926     na      0      0      0       0      222
# 2      pos   72504     na   1594   1052      0      0      0     244   178226
# 3      pos  762958     na     na     na     na     na    776  281128  2186308
# 4      pos  695994     na     na     na     na     na      0       0        0
# ...    ...     ...    ...    ...    ...    ...    ...    ...     ...      ...
# 1292   neg     970      0      2      0      0      0      0       0        0
# 1293   neg   30260     na      0     na      0      0      0       0        0
# 1294   neg   29712     na    272    252      0      0      0       0        0
# 1295   neg      14     na     54     30      0      0      0       0        0
# 1296   neg    2240     na     94     90      0      0      0       0        0
#
#       ...   ee_002   ee_003   ee_004   ee_005   ee_006  ee_007  ee_008 ee_009  \
# 0     ...   129862    26872    34044    22472    34362       0       0      0
# 1     ...  7908038  3026002  5025350  2025766  1160638  533834  493800   6914
# 2     ...  1432098   372252   527514   358274   332818  284178    3742      0
# 3     ...       na       na       na       na       na      na      na     na
# 4     ...  1397742   495544   361646    28610     5130     212       0      0
# ...   ...      ...      ...      ...      ...      ...     ...     ...    ...
# 1292  ...     3648     1194     4114     6294    13860   10558      10      0
# 1293  ...   370354   146786   150288    52354    22200   10930    6108     18
# 1294  ...   259826   132912   247568   182490   152068  144332  200862   5246
# 1295  ...      256       44       48       22       16      22       0      0
# 1296  ...      NaN      NaN      NaN      NaN      NaN     NaN     NaN    NaN
#
#      ef_000 eg_000
# 0         0      0
# 1         0      0
# 2         0      0
# 3        na     na
# 4        na     na
# ...     ...    ...
# 1292      0      0
# 1293      0      0
# 1294      0      0
# 1295      0      0
# 1296    NaN    NaN
#
# [1297 rows x 171 columns]

# %%
dataset.isnull().sum()
# Out:
# class     0
# aa_000    0
# ab_000    0
# ac_000    0
# ad_000    0
#          ..
# ee_007    1
# ee_008    1
# ee_009    1
# ef_000    1
# eg_000    1
# Length: 171, dtype: int64

# %%
np.nan
# Out:
# nan

# %%
dataset=dataset.replace("na",np.nan)

# %%
pd.options.display.max_rows=1000

# %%
dataset.isnull().sum()
# Out:
# class        0
# aa_000       0
# ab_000    1002
# ac_000     259
# ad_000     508
# ae_000     187
# af_000     187
# ag_000       8
# ag_001       8
# ag_002       8
# ag_003       8
# ag_004       8
# ag_005       8
# ag_006       8
# ag_007       9
# ag_008       9
# ag_009       9
# ah_000      24
# ai_000      25
# aj_000      25
# ak_000     302
# al_000      25
# am_0        25
# an_000      25
# ao_000      23
# ap_000      25
# aq_000      23
# ar_000     204
# as_000      25
# at_000      25
# au_000      25
# av_000     188
# ax_000     188
# ay_000      10
# ay_001      10
# ay_002      10
# ay_003      10
# ay_004      10
# ay_005      10
# ay_006      10
# ay_007      10
# ay_008      10
# ay_009      10
# az_000      10
# az_001      10
# az_002      10
# az_003      10
# az_004      10
# az_005      10
# az_006      10
# az_007      10
# az_008      10
# az_009      10
# ba_000       9
# ba_001       9
# ba_002       9
# ba_003       9
# ba_004       9
# ba_005       9
# ba_006       9
# ba_007       9
# ba_008       9
# ba_009       9
# bb_000      24
# bc_000     204
# bd_000     204
# be_000     188
# bf_000     188
# bg_000      25
# bh_000      25
# bi_000      23
# bj_000      23
# bk_000     340
# bl_000     395
# bm_000     558
# bn_000     639
# bo_000     680
# bp_000     704
# bq_000     719
# br_000     725
# bs_000      27
# bt_000       7
# bu_000      27
# bv_000      27
# bx_000      62
# by_000       4
# bz_000     204
# ca_000     299
# cb_000      27
# cc_000      62
# cd_000      25
# ce_000     188
# cf_000     509
# cg_000     509
# ch_000     509
# ci_000       7
# cj_000       7
# ck_000       7
# cl_000     238
# cm_000     275
# cn_000       9
# cn_001       9
# cn_002       9
# cn_003       9
# cn_004       9
# cn_005       9
# cn_006       9
# cn_007       9
# cn_008       9
# cn_009       9
# co_000     509
# cp_000     204
# cq_000      27
# cr_000    1002
# cs_000       9
# cs_001       9
# cs_002       9
# cs_003       9
# cs_004       9
# cs_005       9
# cs_006       9
# cs_007       9
# cs_008       9
# cs_009       9
# ct_000     443
# cu_000     443
# cv_000     443
# cx_000     443
# cy_000     443
# cz_000     443
# da_000     443
# db_000     443
# dc_000     443
# dd_000     188
# de_000     204
# df_000     294
# dg_000     294
# dh_000     294
# di_000     294
# dj_000     294
# dk_000     294
# dl_000     294
# dm_000     294
# dn_000      27
# do_000     204
# dp_000     204
# dq_000     204
# dr_000     204
# ds_000     204
# dt_000     204
# du_000     204
# dv_000     204
# dx_000     204
# dy_000     204
# dz_000     204
# ea_000     204
# eb_000     294
# ec_00      290
# ed_000     238
# ee_000      10
# ee_001      10
# ee_002      10
# ee_003      10
# ee_004      10
# ee_005      10
# ee_006      10
# ee_007      10
# ee_008      10
# ee_009      10
# ef_000     204
# eg_000     204
# dtype: int64

# %%
dataset.isnull().sum().sum()
# Out:
# 24835

# %%
pd.DataFrame(dataset.isnull().sum().sort_values(ascending=False)).rename(columns={0:"Null Value Count"})
# Out:
#         Null Value Count
# cr_000              1002
# ab_000              1002
# br_000               725
# bq_000               719
# bp_000               704
# bo_000               680
# bn_000               639
# bm_000               558
# cg_000               509
# co_000               509
# cf_000               509
# ch_000               509
# ad_000               508
# cz_000               443
# da_000               443
# cy_000               443
# cx_000               443
# cv_000               443
# cu_000               443
# db_000               443
# dc_000               443
# ct_000               443
# bl_000               395
# bk_000               340
# ak_000               302
# ca_000               299
# dk_000               294
# eb_000               294
# dj_000               294
# dl_000               294
# dm_000               294
# df_000               294
# dg_000               294
# dh_000               294
# di_000               294
# ec_00                290
# cm_000               275
# ac_000               259
# cl_000               238
# ed_000               238
# bz_000               204
# ef_000               204
# bc_000               204
# bd_000               204
# cp_000               204
# eg_000               204
# dt_000               204
# dr_000               204
# ea_000               204
# dz_000               204
# dy_000               204
# dx_000               204
# dv_000               204
# du_000               204
# ds_000               204
# de_000               204
# dq_000               204
# dp_000               204
# do_000               204
# ar_000               204
# ax_000               188
# ce_000               188
# av_000               188
# be_000               188
# bf_000               188
# dd_000               188
# af_000               187
# ae_000               187
# cc_000                62
# bx_000                62
# dn_000                27
# cb_000                27
# cq_000                27
# bv_000                27
# bu_000                27
# bs_000                27
# am_0                  25
# cd_000                25
# aj_000                25
# ai_000                25
# an_000                25
# ap_000                25
# as_000                25
# at_000                25
# au_000                25
# bg_000                25
# bh_000                25
# al_000                25
# ah_000                24
# bb_000                24
# aq_000                23
# ao_000                23
# bi_000                23
# bj_000                23
# ay_003                10
# ee_007                10
# az_000                10
# ay_009                10
# ay_008                10
# ay_007                10
# ay_006                10
# ay_005                10
# ay_004                10
# ay_002                10
# ee_000                10
# ay_001                10
# ay_000                10
# ee_006                10
# ee_005                10
# ee_004                10
# ee_003                10
# ee_002                10
# ee_001                10
# az_001                10
# ee_008                10
# az_006                10
# az_005                10
# az_007                10
# az_008                10
# az_009                10
# ee_009                10
# az_002                10
# az_003                10
# az_004                10
# ag_009                 9
# ba_000                 9
# ba_001                 9
# ba_002                 9
# ba_003                 9
# cs_001                 9
# ag_008                 9
# cs_002                 9
# ba_004                 9
# ba_005                 9
# ba_006                 9
# ba_007                 9
# ba_008                 9
# ba_009                 9
# ag_007                 9
# cs_005                 9
# cs_006                 9
# cn_008                 9
# cs_008                 9
# cs_004                 9
# cs_003                 9
# cs_007                 9
# cs_000                 9
# cn_009                 9
# cn_007                 9
# cn_006                 9
# cn_005                 9
# cn_004                 9
# cn_003                 9
# cn_002                 9
# cn_001                 9
# cn_000                 9
# cs_009                 9
# ag_000                 8
# ag_004                 8
# ag_001                 8
# ag_002                 8
# ag_003                 8
# ag_005                 8
# ag_006                 8
# cj_000                 7
# bt_000                 7
# ck_000                 7
# ci_000                 7
# by_000                 4
# aa_000                 0
# class                  0

# %%
[feature for feature in dataset.columns if feature not in ['class']]
# Out:
# ['aa_000',
#  'ab_000',
#  'ac_000',
#  'ad_000',
#  'ae_000',
#  'af_000',
#  'ag_000',
#  'ag_001',
#  'ag_002',
#  'ag_003',
#  'ag_004',
#  'ag_005',
#  'ag_006',
#  'ag_007',
#  'ag_008',
#  'ag_009',
#  'ah_000',
#  'ai_000',
#  'aj_000',
#  'ak_000',
#  'al_000',
#  'am_0',
#  'an_000',
#  'ao_000',
#  'ap_000',
#  'aq_000',
#  'ar_000',
#  'as_000',
#  'at_000',
#  'au_000',
#  'av_000',
#  'ax_000',
#  'ay_000',
#  'ay_001',
#  'ay_002',
#  'ay_003',
#  'ay_004',
#  'ay_005',
#  'ay_006',
#  'ay_007',
#  'ay_008',
#  'ay_009',
#  'az_000',
#  'az_001',
#  'az_002',
#  'az_003',
#  'az_004',
#  'az_005',
#  'az_006',
#  'az_007',
#  'az_008',
#  'az_009',
#  'ba_000',
#  'ba_001',
#  'ba_002',
#  'ba_003',
#  'ba_004',
#  'ba_005',
#  'ba_006',
#  'ba_007',
#  'ba_008',
#  'ba_009',
#  'bb_000',
#  'bc_000',
#  'bd_000',
#  'be_000',
#  'bf_000',
#  'bg_000',
#  'bh_000',
#  'bi_000',
#  'bj_000',
#  'bk_000',
#  'bl_000',
#  'bm_000',
#  'bn_000',
#  'bo_000',
#  'bp_000',
#  'bq_000',
#  'br_000',
#  'bs_000',
#  'bt_000',
#  'bu_000',
#  'bv_000',
#  'bx_000',
#  'by_000',
#  'bz_000',
#  'ca_000',
#  'cb_000',
#  'cc_000',
#  'cd_000',
#  'ce_000',
#  'cf_000',
#  'cg_000',
#  'ch_000',
#  'ci_000',
#  'cj_000',
#  'ck_000',
#  'cl_000',
#  'cm_000',
#  'cn_000',
#  'cn_001',
#  'cn_002',
#  'cn_003',
#  'cn_004',
#  'cn_005',
#  'cn_006',
#  'cn_007',
#  'cn_008',
#  'cn_009',
#  'co_000',
#  'cp_000',
#  'cq_000',
#  'cr_000',
#  'cs_000',
#  'cs_001',
#  'cs_002',
#  'cs_003',
#  'cs_004',
#  'cs_005',
#  'cs_006',
#  'cs_007',
#  'cs_008',
#  'cs_009',
#  'ct_000',
#  'cu_000',
#  'cv_000',
#  'cx_000',
#  'cy_000',
#  'cz_000',
#  'da_000',
#  'db_000',
#  'dc_000',
#  'dd_000',
#  'de_000',
#  'df_000',
#  'dg_000',
#  'dh_000',
#  'di_000',
#  'dj_000',
#  'dk_000',
#  'dl_000',
#  'dm_000',
#  'dn_000',
#  'do_000',
#  'dp_000',
#  'dq_000',
#  'dr_000',
#  'ds_000',
#  'dt_000',
#  'du_000',
#  'dv_000',
#  'dx_000',
#  'dy_000',
#  'dz_000',
#  'ea_000',
#  'eb_000',
#  'ec_00',
#  'ed_000',
#  'ee_000',
#  'ee_001',
#  'ee_002',
#  'ee_003',
#  'ee_004',
#  'ee_005',
#  'ee_006',
#  'ee_007',
#  'ee_008',
#  'ee_009',
#  'ef_000',
#  'eg_000']

# %%
### Filling null values in feature with median of that feature
for feature in [feature for feature in dataset.columns if feature not in ['class']]:
    dataset[feature]=dataset[feature].fillna(dataset[feature].median())

# %%
dataset.isnull().sum()
# Out:
# class     0
# aa_000    0
# ab_000    0
# ac_000    0
# ad_000    0
# ae_000    0
# af_000    0
# ag_000    0
# ag_001    0
# ag_002    0
# ag_003    0
# ag_004    0
# ag_005    0
# ag_006    0
# ag_007    0
# ag_008    0
# ag_009    0
# ah_000    0
# ai_000    0
# aj_000    0
# ak_000    0
# al_000    0
# am_0      0
# an_000    0
# ao_000    0
# ap_000    0
# aq_000    0
# ar_000    0
# as_000    0
# at_000    0
# au_000    0
# av_000    0
# ax_000    0
# ay_000    0
# ay_001    0
# ay_002    0
# ay_003    0
# ay_004    0
# ay_005    0
# ay_006    0
# ay_007    0
# ay_008    0
# ay_009    0
# az_000    0
# az_001    0
# az_002    0
# az_003    0
# az_004    0
# az_005    0
# az_006    0
# az_007    0
# az_008    0
# az_009    0
# ba_000    0
# ba_001    0
# ba_002    0
# ba_003    0
# ba_004    0
# ba_005    0
# ba_006    0
# ba_007    0
# ba_008    0
# ba_009    0
# bb_000    0
# bc_000    0
# bd_000    0
# be_000    0
# bf_000    0
# bg_000    0
# bh_000    0
# bi_000    0
# bj_000    0
# bk_000    0
# bl_000    0
# bm_000    0
# bn_000    0
# bo_000    0
# bp_000    0
# bq_000    0
# br_000    0
# bs_000    0
# bt_000    0
# bu_000    0
# bv_000    0
# bx_000    0
# by_000    0
# bz_000    0
# ca_000    0
# cb_000    0
# cc_000    0
# cd_000    0
# ce_000    0
# cf_000    0
# cg_000    0
# ch_000    0
# ci_000    0
# cj_000    0
# ck_000    0
# cl_000    0
# cm_000    0
# cn_000    0
# cn_001    0
# cn_002    0
# cn_003    0
# cn_004    0
# cn_005    0
# cn_006    0
# cn_007    0
# cn_008    0
# cn_009    0
# co_000    0
# cp_000    0
# cq_000    0
# cr_000    0
# cs_000    0
# cs_001    0
# cs_002    0
# cs_003    0
# cs_004    0
# cs_005    0
# cs_006    0
# cs_007    0
# cs_008    0
# cs_009    0
# ct_000    0
# cu_000    0
# cv_000    0
# cx_000    0
# cy_000    0
# cz_000    0
# da_000    0
# db_000    0
# dc_000    0
# dd_000    0
# de_000    0
# df_000    0
# dg_000    0
# dh_000    0
# di_000    0
# dj_000    0
# dk_000    0
# dl_000    0
# dm_000    0
# dn_000    0
# do_000    0
# dp_000    0
# dq_000    0
# dr_000    0
# ds_000    0
# dt_000    0
# du_000    0
# dv_000    0
# dx_000    0
# dy_000    0
# dz_000    0
# ea_000    0
# eb_000    0
# ec_00     0
# ed_000    0
# ee_000    0
# ee_001    0
# ee_002    0
# ee_003    0
# ee_004    0
# ee_005    0
# ee_006    0
# ee_007    0
# ee_008    0
# ee_009    0
# ef_000    0
# eg_000    0
# dtype: int64

# %%
dataset.isnull().sum().sum()
# Out:
# 0

# %%
dataset.isnull().sum()
# Out:
# class     0
# aa_000    0
# ab_000    0
# ac_000    0
# ad_000    0
# ae_000    0
# af_000    0
# ag_000    0
# ag_001    0
# ag_002    0
# ag_003    0
# ag_004    0
# ag_005    0
# ag_006    0
# ag_007    0
# ag_008    0
# ag_009    0
# ah_000    0
# ai_000    0
# aj_000    0
# ak_000    0
# al_000    0
# am_0      0
# an_000    0
# ao_000    0
# ap_000    0
# aq_000    0
# ar_000    0
# as_000    0
# at_000    0
# au_000    0
# av_000    0
# ax_000    0
# ay_000    0
# ay_001    0
# ay_002    0
# ay_003    0
# ay_004    0
# ay_005    0
# ay_006    0
# ay_007    0
# ay_008    0
# ay_009    0
# az_000    0
# az_001    0
# az_002    0
# az_003    0
# az_004    0
# az_005    0
# az_006    0
# az_007    0
# az_008    0
# az_009    0
# ba_000    0
# ba_001    0
# ba_002    0
# ba_003    0
# ba_004    0
# ba_005    0
# ba_006    0
# ba_007    0
# ba_008    0
# ba_009    0
# bb_000    0
# bc_000    0
# bd_000    0
# be_000    0
# bf_000    0
# bg_000    0
# bh_000    0
# bi_000    0
# bj_000    0
# bk_000    0
# bl_000    0
# bm_000    0
# bn_000    0
# bo_000    0
# bp_000    0
# bq_000    0
# br_000    0
# bs_000    0
# bt_000    0
# bu_000    0
# bv_000    0
# bx_000    0
# by_000    0
# bz_000    0
# ca_000    0
# cb_000    0
# cc_000    0
# cd_000    0
# ce_000    0
# cf_000    0
# cg_000    0
# ch_000    0
# ci_000    0
# cj_000    0
# ck_000    0
# cl_000    0
# cm_000    0
# cn_000    0
# cn_001    0
# cn_002    0
# cn_003    0
# cn_004    0
# cn_005    0
# cn_006    0
# cn_007    0
# cn_008    0
# cn_009    0
# co_000    0
# cp_000    0
# cq_000    0
# cr_000    0
# cs_000    0
# cs_001    0
# cs_002    0
# cs_003    0
# cs_004    0
# cs_005    0
# cs_006    0
# cs_007    0
# cs_008    0
# cs_009    0
# ct_000    0
# cu_000    0
# cv_000    0
# cx_000    0
# cy_000    0
# cz_000    0
# da_000    0
# db_000    0
# dc_000    0
# dd_000    0
# de_000    0
# df_000    0
# dg_000    0
# dh_000    0
# di_000    0
# dj_000    0
# dk_000    0
# dl_000    0
# dm_000    0
# dn_000    0
# do_000    0
# dp_000    0
# dq_000    0
# dr_000    0
# ds_000    0
# dt_000    0
# du_000    0
# dv_000    0
# dx_000    0
# dy_000    0
# dz_000    0
# ea_000    0
# eb_000    0
# ec_00     0
# ed_000    0
# ee_000    0
# ee_001    0
# ee_002    0
# ee_003    0
# ee_004    0
# ee_005    0
# ee_006    0
# ee_007    0
# ee_008    0
# ee_009    0
# ef_000    0
# eg_000    0
# dtype: int64

# %%
pd.DataFrame(dataset.isnull().sum().sort_values(ascending=False)).rename(columns={0:"Null Value Count"})
# Out:
#         Null Value Count
# class                  0
# cs_003                 0
# cn_009                 0
# co_000                 0
# cp_000                 0
# cq_000                 0
# cr_000                 0
# cs_000                 0
# cs_001                 0
# cs_002                 0
# cs_004                 0
# cy_000                 0
# cs_005                 0
# cs_006                 0
# cs_007                 0
# cs_008                 0
# cs_009                 0
# ct_000                 0
# cu_000                 0
# cv_000                 0
# cn_008                 0
# cn_007                 0
# cn_006                 0
# cn_005                 0
# cb_000                 0
# cc_000                 0
# cd_000                 0
# ce_000                 0
# cf_000                 0
# cg_000                 0
# ch_000                 0
# ci_000                 0
# cj_000                 0
# ck_000                 0
# cl_000                 0
# cm_000                 0
# cn_000                 0
# cn_001                 0
# cn_002                 0
# cn_003                 0
# cn_004                 0
# cx_000                 0
# cz_000                 0
# bz_000                 0
# ee_001                 0
# dx_000                 0
# dy_000                 0
# dz_000                 0
# ea_000                 0
# eb_000                 0
# ec_00                  0
# ed_000                 0
# ee_000                 0
# ee_002                 0
# da_000                 0
# ee_003                 0
# ee_004                 0
# ee_005                 0
# ee_006                 0
# ee_007                 0
# ee_008                 0
# ee_009                 0
# ef_000                 0
# dv_000                 0
# du_000                 0
# dt_000                 0
# ds_000                 0
# db_000                 0
# dc_000                 0
# dd_000                 0
# de_000                 0
# df_000                 0
# dg_000                 0
# dh_000                 0
# di_000                 0
# dj_000                 0
# dk_000                 0
# dl_000                 0
# dm_000                 0
# dn_000                 0
# do_000                 0
# dp_000                 0
# dq_000                 0
# dr_000                 0
# ca_000                 0
# by_000                 0
# aa_000                 0
# av_000                 0
# an_000                 0
# ao_000                 0
# ap_000                 0
# aq_000                 0
# ar_000                 0
# as_000                 0
# at_000                 0
# au_000                 0
# ax_000                 0
# ay_009                 0
# ay_000                 0
# ay_001                 0
# ay_002                 0
# ay_003                 0
# ay_004                 0
# ay_005                 0
# ay_006                 0
# ay_007                 0
# am_0                   0
# al_000                 0
# ak_000                 0
# aj_000                 0
# ab_000                 0
# ac_000                 0
# ad_000                 0
# ae_000                 0
# af_000                 0
# ag_000                 0
# ag_001                 0
# ag_002                 0
# ag_003                 0
# ag_004                 0
# ag_005                 0
# ag_006                 0
# ag_007                 0
# ag_008                 0
# ag_009                 0
# ah_000                 0
# ai_000                 0
# ay_008                 0
# az_000                 0
# bx_000                 0
# bm_000                 0
# be_000                 0
# bf_000                 0
# bg_000                 0
# bh_000                 0
# bi_000                 0
# bj_000                 0
# bk_000                 0
# bl_000                 0
# bn_000                 0
# az_001                 0
# bo_000                 0
# bp_000                 0
# bq_000                 0
# br_000                 0
# bs_000                 0
# bt_000                 0
# bu_000                 0
# bv_000                 0
# bd_000                 0
# bc_000                 0
# bb_000                 0
# ba_009                 0
# az_002                 0
# az_003                 0
# az_004                 0
# az_005                 0
# az_006                 0
# az_007                 0
# az_008                 0
# az_009                 0
# ba_000                 0
# ba_001                 0
# ba_002                 0
# ba_003                 0
# ba_004                 0
# ba_005                 0
# ba_006                 0
# ba_007                 0
# ba_008                 0
# eg_000                 0

# %%
dataset.head()
# Out:
#   class  aa_000 ab_000 ac_000 ad_000 ae_000 af_000 ag_000  ag_001   ag_002  \
# 0   pos  153204      0    182  180.0      0      0      0       0        0
# 1   pos  453236    0.0   2926  180.0      0      0      0       0      222
# 2   pos   72504    0.0   1594   1052      0      0      0     244   178226
# 3   pos  762958    0.0  236.0  180.0    0.0    0.0    776  281128  2186308
# 4   pos  695994    0.0  236.0  180.0    0.0    0.0      0       0        0
#
#    ...    ee_002    ee_003    ee_004    ee_005    ee_006    ee_007   ee_008  \
# 0  ...    129862     26872     34044     22472     34362         0        0
# 1  ...   7908038   3026002   5025350   2025766   1160638    533834   493800
# 2  ...   1432098    372252    527514    358274    332818    284178     3742
# 3  ...  396902.0  192398.0  394338.0  333178.0  213910.0  119050.0  28902.0
# 4  ...   1397742    495544    361646     28610      5130       212        0
#
#   ee_009 ef_000 eg_000
# 0      0      0      0
# 1   6914      0      0
# 2      0      0      0
# 3    0.0    0.0    0.0
# 4      0    0.0    0.0
#
# [5 rows x 171 columns]

# %%
X=dataset.drop("class",axis=1)

# %%
y=dataset["class"]

# %%
X.info(verbose=True,show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1297 entries, 0 to 1296
# Data columns (total 170 columns):
#  #    Column  Non-Null Count  Dtype
# ---   ------  --------------  -----
#  0    aa_000  1297 non-null   int64
#  1    ab_000  1297 non-null   object
#  2    ac_000  1297 non-null   object
#  3    ad_000  1297 non-null   object
#  4    ae_000  1297 non-null   object
#  5    af_000  1297 non-null   object
#  6    ag_000  1297 non-null   object
#  7    ag_001  1297 non-null   object
#  8    ag_002  1297 non-null   object
#  9    ag_003  1297 non-null   object
#  10   ag_004  1297 non-null   object
#  11   ag_005  1297 non-null   object
#  12   ag_006  1297 non-null   object
#  13   ag_007  1297 non-null   object
#  14   ag_008  1297 non-null   object
#  15   ag_009  1297 non-null   object
#  16   ah_000  1297 non-null   object
#  17   ai_000  1297 non-null   object
#  18   aj_000  1297 non-null   object
#  19   ak_000  1297 non-null   object
#  20   al_000  1297 non-null   object
#  21   am_0    1297 non-null   object
#  22   an_000  1297 non-null   object
#  23   ao_000  1297 non-null   object
#  24   ap_000  1297 non-null   object
#  25   aq_000  1297 non-null   object
#  26   ar_000  1297 non-null   object
#  27   as_000  1297 non-null   object
#  28   at_000  1297 non-null   object
#  29   au_000  1297 non-null   object
#  30   av_000  1297 non-null   object
#  31   ax_000  1297 non-null   object
#  32   ay_000  1297 non-null   object
#  33   ay_001  1297 non-null   object
#  34   ay_002  1297 non-null   object
#  35   ay_003  1297 non-null   object
#  36   ay_004  1297 non-null   object
#  37   ay_005  1297 non-null   object
#  38   ay_006  1297 non-null   object
#  39   ay_007  1297 non-null   object
#  40   ay_008  1297 non-null   object
#  41   ay_009  1297 non-null   object
#  42   az_000  1297 non-null   object
#  43   az_001  1297 non-null   object
#  44   az_002  1297 non-null   object
#  45   az_003  1297 non-null   object
#  46   az_004  1297 non-null   object
#  47   az_005  1297 non-null   object
#  48   az_006  1297 non-null   object
#  49   az_007  1297 non-null   object
#  50   az_008  1297 non-null   object
#  51   az_009  1297 non-null   object
#  52   ba_000  1297 non-null   object
#  53   ba_001  1297 non-null   object
#  54   ba_002  1297 non-null   object
#  55   ba_003  1297 non-null   object
#  56   ba_004  1297 non-null   object
#  57   ba_005  1297 non-null   object
#  58   ba_006  1297 non-null   object
#  59   ba_007  1297 non-null   object
#  60   ba_008  1297 non-null   object
#  61   ba_009  1297 non-null   object
#  62   bb_000  1297 non-null   object
#  63   bc_000  1297 non-null   object
#  64   bd_000  1297 non-null   object
#  65   be_000  1297 non-null   object
#  66   bf_000  1297 non-null   object
#  67   bg_000  1297 non-null   object
#  68   bh_000  1297 non-null   object
#  69   bi_000  1297 non-null   object
#  70   bj_000  1297 non-null   object
#  71   bk_000  1297 non-null   object
#  72   bl_000  1297 non-null   object
#  73   bm_000  1297 non-null   object
#  74   bn_000  1297 non-null   object
#  75   bo_000  1297 non-null   object
#  76   bp_000  1297 non-null   object
#  77   bq_000  1297 non-null   object
#  78   br_000  1297 non-null   object
#  79   bs_000  1297 non-null   object
#  80   bt_000  1297 non-null   object
#  81   bu_000  1297 non-null   object
#  82   bv_000  1297 non-null   object
#  83   bx_000  1297 non-null   object
#  84   by_000  1297 non-null   object
#  85   bz_000  1297 non-null   object
#  86   ca_000  1297 non-null   object
#  87   cb_000  1297 non-null   object
#  88   cc_000  1297 non-null   object
#  89   cd_000  1297 non-null   object
#  90   ce_000  1297 non-null   object
#  91   cf_000  1297 non-null   object
#  92   cg_000  1297 non-null   object
#  93   ch_000  1297 non-null   object
#  94   ci_000  1297 non-null   object
#  95   cj_000  1297 non-null   object
#  96   ck_000  1297 non-null   object
#  97   cl_000  1297 non-null   object
#  98   cm_000  1297 non-null   object
#  99   cn_000  1297 non-null   object
#  100  cn_001  1297 non-null   object
#  101  cn_002  1297 non-null   object
#  102  cn_003  1297 non-null   object
#  103  cn_004  1297 non-null   object
#  104  cn_005  1297 non-null   object
#  105  cn_006  1297 non-null   object
#  106  cn_007  1297 non-null   object
#  107  cn_008  1297 non-null   object
#  108  cn_009  1297 non-null   object
#  109  co_000  1297 non-null   object
#  110  cp_000  1297 non-null   object
#  111  cq_000  1297 non-null   object
#  112  cr_000  1297 non-null   object
#  113  cs_000  1297 non-null   object
#  114  cs_001  1297 non-null   object
#  115  cs_002  1297 non-null   object
#  116  cs_003  1297 non-null   object
#  117  cs_004  1297 non-null   object
#  118  cs_005  1297 non-null   object
#  119  cs_006  1297 non-null   object
#  120  cs_007  1297 non-null   object
#  121  cs_008  1297 non-null   object
#  122  cs_009  1297 non-null   object
#  123  ct_000  1297 non-null   object
#  124  cu_000  1297 non-null   object
#  125  cv_000  1297 non-null   object
#  126  cx_000  1297 non-null   object
#  127  cy_000  1297 non-null   object
#  128  cz_000  1297 non-null   object
#  129  da_000  1297 non-null   object
#  130  db_000  1297 non-null   object
#  131  dc_000  1297 non-null   object
#  132  dd_000  1297 non-null   object
#  133  de_000  1297 non-null   object
#  134  df_000  1297 non-null   object
#  135  dg_000  1297 non-null   object
#  136  dh_000  1297 non-null   object
#  137  di_000  1297 non-null   object
#  138  dj_000  1297 non-null   object
#  139  dk_000  1297 non-null   object
#  140  dl_000  1297 non-null   object
#  141  dm_000  1297 non-null   object
#  142  dn_000  1297 non-null   object
#  143  do_000  1297 non-null   object
#  144  dp_000  1297 non-null   object
#  145  dq_000  1297 non-null   object
#  146  dr_000  1297 non-null   object
#  147  ds_000  1297 non-null   object
#  148  dt_000  1297 non-null   object
#  149  du_000  1297 non-null   object
#  150  dv_000  1297 non-null   object
#  151  dx_000  1297 non-null   object
#  152  dy_000  1297 non-null   object
#  153  dz_000  1297 non-null   object
#  154  ea_000  1297 non-null   object
#  155  eb_000  1297 non-null   object
#  156  ec_00   1297 non-null   object
#  157  ed_000  1297 non-null   object
#  158  ee_000  1297 non-null   object
#  159  ee_001  1297 non-null   object
#  160  ee_002  1297 non-null   object
#  161  ee_003  1297 non-null   object
#  162  ee_004  1297 non-null   object
#  163  ee_005  1297 non-null   object
#  164  ee_006  1297 non-null   object
#  165  ee_007  1297 non-null   object
#  166  ee_008  1297 non-null   object
#  167  ee_009  1297 non-null   object
#  168  ef_000  1297 non-null   object
#  169  eg_000  1297 non-null   object
# dtypes: int64(1), object(169)
# memory usage: 1.7+ MB

# %%
y = pd.get_dummies(y,drop_first=True)

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1037, 170)
# (260, 170)
# (1037, 1)
# (260, 1)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
# Importing the Keras libraries and packages
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

# %%
classifier=Sequential()

classifier.add(Dense(units=10,kernel_initializer='he_uniform',activation='relu',input_dim =170))

classifier.add(Dense(units = 10, kernel_initializer = 'he_uniform',activation='relu'))

classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# %%
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy',metrics=['accuracy'])

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                1710
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 1,831
# Trainable params: 1,831
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train
# Out:
# array([[-0.66286078, -0.14052712,  2.83149983, ..., -0.22676224,
#         -0.0439587 , -0.05386422],
#        [-0.63123484, -0.14052712, -0.35317162, ..., -0.22676224,
#         -0.0439587 , -0.05386422],
#        [ 2.07497412, -0.14052712, -0.35317169, ..., -0.18109624,
#         -0.0439587 , -0.05386422],
#        ...,
#        [-0.66519587, -0.14052712, -0.35317169, ..., -0.22676224,
#         -0.0439587 , -0.05386422],
#        [-0.66164945, -0.14052712,  2.83149983, ..., -0.22676224,
#         -0.0439587 , -0.05386422],
#        [-0.66601316, -0.14052712,  2.83149983, ..., -0.22676224,
#         -0.0439587 , -0.05386422]])

# %%
model_history=classifier.fit(X_train,y_train,batch_size=10,epochs=30,validation_split=0.25)
# Out:
# Epoch 1/30
# 78/78 [==============================] - 6s 7ms/step - loss: 0.3495 - accuracy: 0.9086 - val_loss: 0.2127 - val_accuracy: 0.9385
# Epoch 2/30
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1942 - accuracy: 0.9369 - val_loss: 0.1800 - val_accuracy: 0.9500
# Epoch 3/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.1637 - accuracy: 0.9485 - val_loss: 0.1686 - val_accuracy: 0.9500
# Epoch 4/30
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1402 - accuracy: 0.9550 - val_loss: 0.1682 - val_accuracy: 0.9538
# Epoch 5/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.1247 - accuracy: 0.9562 - val_loss: 0.1575 - val_accuracy: 0.9538
# Epoch 6/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.1102 - accuracy: 0.9627 - val_loss: 0.1540 - val_accuracy: 0.9577
# Epoch 7/30
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1012 - accuracy: 0.9665 - val_loss: 0.1508 - val_accuracy: 0.9577
# Epoch 8/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0943 - accuracy: 0.9691 - val_loss: 0.1483 - val_accuracy: 0.9538
# Epoch 9/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0880 - accuracy: 0.9704 - val_loss: 0.1468 - val_accuracy: 0.9538
# Epoch 10/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0823 - accuracy: 0.9743 - val_loss: 0.1459 - val_accuracy: 0.9500
# Epoch 11/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0782 - accuracy: 0.9768 - val_loss: 0.1441 - val_accuracy: 0.9500
# Epoch 12/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0736 - accuracy: 0.9781 - val_loss: 0.1492 - val_accuracy: 0.9500
# Epoch 13/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0712 - accuracy: 0.9807 - val_loss: 0.1454 - val_accuracy: 0.9538
# Epoch 14/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0672 - accuracy: 0.9807 - val_loss: 0.1447 - val_accuracy: 0.9577
# Epoch 15/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0643 - accuracy: 0.9820 - val_loss: 0.1448 - val_accuracy: 0.9538
# Epoch 16/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0610 - accuracy: 0.9846 - val_loss: 0.1519 - val_accuracy: 0.9538
# Epoch 17/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0587 - accuracy: 0.9846 - val_loss: 0.1468 - val_accuracy: 0.9538
# Epoch 18/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0565 - accuracy: 0.9858 - val_loss: 0.1493 - val_accuracy: 0.9577
# Epoch 19/30
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0545 - accuracy: 0.9884 - val_loss: 0.1535 - val_accuracy: 0.9577
# Epoch 20/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0517 - accuracy: 0.9884 - val_loss: 0.1540 - val_accuracy: 0.9538
# Epoch 21/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0510 - accuracy: 0.9884 - val_loss: 0.1560 - val_accuracy: 0.9615
# Epoch 22/30
# 78/78 [==============================] - 1s 7ms/step - loss: 0.0479 - accuracy: 0.9871 - val_loss: 0.1612 - val_accuracy: 0.9462
# Epoch 23/30
# 78/78 [==============================] - 1s 7ms/step - loss: 0.0470 - accuracy: 0.9884 - val_loss: 0.1642 - val_accuracy: 0.9462
# Epoch 24/30
# 78/78 [==============================] - 1s 8ms/step - loss: 0.0457 - accuracy: 0.9884 - val_loss: 0.1671 - val_accuracy: 0.9615
# Epoch 25/30
# 78/78 [==============================] - 1s 8ms/step - loss: 0.0444 - accuracy: 0.9884 - val_loss: 0.1705 - val_accuracy: 0.9538
# Epoch 26/30
# 78/78 [==============================] - 1s 7ms/step - loss: 0.0431 - accuracy: 0.9884 - val_loss: 0.1787 - val_accuracy: 0.9500
# Epoch 27/30
# 78/78 [==============================] - 1s 7ms/step - loss: 0.0431 - accuracy: 0.9884 - val_loss: 0.1790 - val_accuracy: 0.9462
# Epoch 28/30
# 78/78 [==============================] - 1s 8ms/step - loss: 0.0412 - accuracy: 0.9897 - val_loss: 0.1833 - val_accuracy: 0.9500
# Epoch 29/30
# 78/78 [==============================] - 1s 7ms/step - loss: 0.0404 - accuracy: 0.9884 - val_loss: 0.1850 - val_accuracy: 0.9500
# Epoch 30/30
# 78/78 [==============================] - 1s 8ms/step - loss: 0.0383 - accuracy: 0.9897 - val_loss: 0.1913 - val_accuracy: 0.9538

# %%
model_history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
model_history.history['accuracy']
# Out:
# [0.9086229205131531,
#  0.9369369149208069,
#  0.9485199451446533,
#  0.954954981803894,
#  0.9562419652938843,
#  0.9626769423484802,
#  0.9665379524230957,
#  0.969111979007721,
#  0.9703989624977112,
#  0.9742599725723267,
#  0.9768339991569519,
#  0.9781209826469421,
#  0.9806950092315674,
#  0.9806950092315674,
#  0.9819819927215576,
#  0.9845559597015381,
#  0.9845559597015381,
#  0.9858430027961731,
#  0.9884169697761536,
#  0.9884169697761536,
#  0.9884169697761536,
#  0.9871299862861633,
#  0.9884169697761536,
#  0.9884169697761536,
#  0.9884169697761536,
#  0.9884169697761536,
#  0.9884169697761536,
#  0.9897040128707886,
#  0.9884169697761536,
#  0.9897040128707886]

# %%
# list all data in history

print(model_history.history.keys())
# summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for accuracy
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model accuracy')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
X_test.shape
# Out:
# (260, 170)

# %%
y_pred=classifier.predict(X_test)
# Out:
# 9/9 [==============================] - 0s 2ms/step

# %%
#for the sigmoid my threshold is 0.

# %%
y_pred=y_pred>0.5

# %%
y_pred.shape
# Out:
# (260, 1)

# %%
from sklearn.metrics import confusion_matrix

# %%
y_test.shape
# Out:
# (260, 1)

# %%
y_pred.shape
# Out:
# (260, 1)

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[163,  14],
#        [ 11,  72]])

# %%
import time
import os

def saveModel_path(model_dir="SAVED_MODELS"):
    os.makedirs(model_dir, exist_ok=True)
    fileName = time.strftime("Model_%Y_%m_%d_%H_%M_%S_.h5")
    model_path = os.path.join(model_dir, fileName)
    print(f"your model will be saved at the following location\n{model_path}")
    return model_path

# %%
classifier.save(saveModel_path())
# Out:
# your model will be saved at the following location
# SAVED_MODELS/Model_2023_08_24_11_33_39_.h5

# %%
#hyperparameter tuning with keras tuner

# !pip install keras-tuner --upgrade
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.3.5-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2023.7.22)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.3.5 kt-legacy-1.0.5

# %%
from kerastuner.tuners import RandomSearch
# Out:
# <ipython-input-52-94471a811b41>:1: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import RandomSearch

# %%
def build_model(hp):
  model=Sequential()
  model.add(Dense(units=32,kernel_initializer = 'he_uniform',activation='relu',input_dim=170))
  model.add(Dense(units = 32, kernel_initializer = 'he_uniform',activation='relu'))
  model.add(Dense(1,activation='sigmoid'))
  optimizer=hp.Choice("optimizer",values=["adam","sgd","rmsprop","adadelta"])
  model.compile(optimizer=optimizer,loss='binary_crossentropy',metrics=['accuracy'])
  return model

# %%
tuner=RandomSearch(build_model,objective='val_accuracy',max_trials=5,directory='project1',project_name='aps-fault')

# %%
tuner.search(X_train,y_train,validation_data=(X_test,y_test),epochs=5)

# %%
tuner.get_best_hyperparameters()[0].values
# Out:
# {'optimizer': 'adam'}

# %%
mymodel=tuner.get_best_models(num_models=1)[0]

# %%
mymodel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                5472
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 6,561
# Trainable params: 6,561
# Non-trainable params: 0
# _________________________________________________________________
